# %%
import pandas as pd
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
sarah = pd.read_csv("../csv/our_txs.csv")

# %%
x = sarah['sending_user'].value_counts()

# %%
tx = x.index

# %%
tx
# Out:
# Index(['4885ddf124a0f97b5a3775a12de0274d342d12842ebe59520359f976721ac8c3',
#        '3b37999f79fde9c4f9397988540d3828ab33e01a462362785c8524b38596fc5b',
#        '5a09f4ef0e91bc7bc044365cd27236fe4ac3c02088ac21ab51c93c8a11d33d4b',
#        '5d340d669616e3b930521828a85fcf1d3d061b32ea13e8061df62f131ddab978',
#        '011962765ac1b8b16a730cfd015da8382537570b0f96f74347c0537f43dabb60',
#        '397b4021cf68948d2f0614678b49ab18f43e6332b1601924f4ed00d491a61509',
#        '3d886d14e3f7f8f3ac7286e2b14003a06111e2e62bc9b1e15a2a961c878fef16',
#        '47cc85842dcc5d6b0e3ea6c2ffd8610d9ab6f12d0e213beaf0f245d80edd60d4',
#        'f42c59b68be73f203dbe8136b75af48895e18238b189dc5a0f820d0bf4ca0b09',
#        'bbba72c5a8adf010200e51b96ddc40800592f670c947f43faa309fc433e267b8',
#        ...
#        'cec06e6f2fe699aa0f0f357b2eca4b02263e5cbf862ed312fa53666e428b667a',
#        '3e88871fbc3c5d1f0b2b2e53ca0d28f00c46a09546843360331dbf8fa70b4afb',
# ...

# %%
df = pd.read_pickle('../pickles/df/all_blocks.pickle')

# %%
df.to_csv('./all_blocks.csv', sep='\t', encoding='utf-8')

# %%
sarah.loc[sarah["sending_user"]=='sarah']
# Out:
#                                     iadr sending_user  \
# 3     1FRr2J14eDsLogCz7sbKNHUvqVz7Xccehw        sarah
# 12    16i6WcSK1EsSSHhAJNvDx6ZkEYESxCdiPm        sarah
# 13    16i6WcSK1EsSSHhAJNvDx6ZkEYESxCdiPm        sarah
# 14    15pRcFJGv3UHdJV5cCmoYD239QRvD3aaSo        sarah
# 15    15pRcFJGv3UHdJV5cCmoYD239QRvD3aaSo        sarah
# 19    17ue1SngiYzg4AtSFFxSvBBesJLbDFnQzU        sarah
# 22    1LS7HD6XhAS6RwfnQv9W1EKqBibWujdWaD        sarah
# 23    1LS7HD6XhAS6RwfnQv9W1EKqBibWujdWaD        sarah
# 24    1892MXh22ae9jv4UmBRpwM5uMeAUfhrk7m        sarah
# 25    1C2YLRT3AuzdyPNqrbm1wAgoj3yGnawFvD        sarah
# 34    1C2YLRT3AuzdyPNqrbm1wAgoj3yGnawFvD        sarah
# 38    1C2YLRT3AuzdyPNqrbm1wAgoj3yGnawFvD        sarah
# 42    13x21j8RvYToAjbrZWDPmEoX1Xp5wvWRMG        sarah
# 43    13x21j8RvYToAjbrZWDPmEoX1Xp5wvWRMG        sarah
# 44    1C2YLRT3AuzdyPNqrbm1wAgoj3yGnawFvD        sarah
# 45    1C2YLRT3AuzdyPNqrbm1wAgoj3yGnawFvD        sarah
# ...
