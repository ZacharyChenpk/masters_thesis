# %%
import pandas as pd 
import pickle
import time
import py2neo
import urllib3
import os.path
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
#block_list = [364133,368580,354281]

# %%
def query_database(query):
    # REMEMBER TO BE CONNECTED TO IMPERIAL WIFI!
    graph_db = py2neo.Graph("https://dsi-bitcoin.doc.ic.ac.uk:7473/db/data/", auth=("adi", "aditi123"))
    return graph_db.run(query)

def get_block_data(blk):
    query_string = """
                    MATCH (b:Block) <-[:MINED_IN]- (t:Tx) <-[:IN]- (txi:TxIn) <-[:UNLOCK]- (iadr:Address)
                    WHERE b.height = {}
                    MATCH (txi) <-[:SPENT]- (txo_in:TxOut) 
                    MATCH (oadr:Address) <-[:LOCK]- (txo_out:TxOut) <-[:OUT]- (t)
                    
                    RETURN iadr.address as iadr, oadr.address as oadr, txo_in.value as input_val, txo_out.value as output_val, ID(txo_in) as id_txo_in, ID(txi) as id_txi, ID(t) as id_t, ID(txo_out) as id_txo_out
                    """.format(blk)
    return query_string

def get_coinbase(blk):
    query_string = """
                    MATCH (b:Block) <-[:MINED_IN]- (t:Tx)<-[:IN]-(cb:CBscript)
                    MATCH (oadr:Address) <-[:LOCK]- (txo_out:TxOut) <-[:OUT]- (t)
                    WHERE b.height = {}
                    RETURN                       oadr.address as oadr,                            txo_out.value as output_val,                          ID(cb) as id_txi, ID(t) as id_t, ID(txo_out) as id_txo_out             
                    """.format(blk)
    return query_string

def check_block(first_block, last_block):
    query_string = """ 
                    MATCH (b:Block) 
                    WHERE b.height >= {} AND b.height <= {}
                    RETURN b
                    """.format(first_block, last_block)
    return query_string

def write_to_csv(result,string):

    df = result.to_data_frame()

    if (df.empty):
        print("Something went wrong, there is no data for this/these blocks")
    else:
        df.to_csv('{}.csv'.format(string), encoding='utf-8', index=False)
        
def seen_before_out(block, adr):
    params = {'block':block,'adr':adr}
    query_string = """
                    MATCH (a:Address) <-[:LOCK]- (to:TxOut) <-[:OUT]- (t1:Tx)-[:MINED_IN]->(b1:Block)
                    WHERE a.address = "{adr}" AND b1.height<{block}
                    RETURN b1.height LIMIT 1
                    """.format(**params)
    
    data_fr = query_database(query_string).to_data_frame()
    if data_fr.empty:
        return False
    return True

def seen_before_in(block, adr):
    params = {'block':block,'adr':adr}
    query_string = """
                    MATCH (a:Address) -[:UNLOCK]-> (ti:TxIn) -[:IN]-> (t2:Tx)-[:MINED_IN]->(b2:Block)
                    WHERE a.address = "{adr}" AND b2.height<{block}
                    RETURN b2.height LIMIT 1
                    """.format(**params)
    data_fr = query_database(query_string).to_data_frame()
    if data_fr.empty:
        return False
    return True

#temptime = time.time()
#starttime = time.time()

def all_block_data(block):
#for block in range(first_block,last_block+1,1):
    if(os.path.exists("../pickles/df/{}.pickle".format(block))):
        print('df already exists')
        df = pd.read_pickle("../pickles/df/{}.pickle".format(block))
        print('Got all block data')
        return df
    
    result = query_database(get_block_data(block))
    df = result.to_data_frame()
    
    #Append coinbase txs to dataframe
    result_cb = query_database(get_coinbase(block))
    df_cb = result_cb.to_data_frame()
    df_cb.insert(0, 'iadr', '0')
    df_cb.insert(3, 'id_txo_in', 0)
    df_cb.insert(5, 'input_val', 0)
    
    df = df.append(df_cb)
    df = df.reset_index()
    df = df.drop(columns=['index'])
    df.to_pickle("../pickles/df/{}.pickle".format(block))
    print('Got all block data')
    return df
    #print(block, " processed in ", time.time()-temptime)
    #temptime = time.time()  
#print("Total time to process everything: {}".format(time.time()-starttime))


initaltime = time.time()
#for block in block_list:
for block in range(400600,402200+1,1):
    starttime = time.time()
    print(block)
    if(os.path.exists('../pickles/otc/otc_{}.pickle'.format(block))):
        print('otc already exists')
        continue
    
    df = all_block_data(block)
    
    if df.empty:
        print("Block {} contained nothing".format(block))
        continue

    addresses = list(df.oadr.value_counts().index)

    not_seen =[]
    import time

    temptime = time.time()

    for adr in addresses:
        if seen_before_in(block, adr):
            continue
        elif seen_before_out(block, adr):
            continue 
        else:
            not_seen.append(adr)
        #print(adr, " processed in ", time.time()-temptime)
        temptime = time.time()
    print('otc done')
    
    with open('../pickles/otc/out.txt', 'a') as f:
        print("Total time to process block {}: {}".format(block, time.time()-starttime), file=f)
        
    with open('../pickles/otc/otc_{}.pickle'.format(block),'wb') as f:
        pickle.dump(not_seen,f)

with open('../pickles/otc/out.txt', 'a') as f:
    print("Total time to process everything: {}".format(time.time()-initaltime), file=f)
# Out:
# 400600
# otc already exists
# 400601
# otc already exists
# 400602
# otc already exists
# 400603
# otc already exists
# 400604
# otc already exists
# 400605
# otc already exists
# 400606
# otc already exists
# 400607
# otc already exists
# 400608
# otc already exists
# 400609
# otc already exists
# 400610
# otc already exists
# 400611
# otc already exists
# 400612
# otc already exists
# 400613
# otc already exists
# 400614
# otc already exists
# 400615
# otc already exists
# 400616
# otc already exists
# 400617
# otc already exists
# 400618
# otc already exists
# 400619
# otc already exists
# 400620
# otc already exists
# 400621
# otc already exists
# 400622
# otc already exists
# 400623
# otc already exists
# 400624
# otc already exists
# 400625
# otc already exists
# 400626
# otc already exists
# 400627
# otc already exists
# 400628
# otc already exists
# 400629
# otc already exists
# 400630
# otc already exists
# 400631
# otc already exists
# 400632
# otc already exists
# 400633
# otc already exists
# 400634
# otc already exists
# 400635
# otc already exists
# 400636
# otc already exists
# 400637
# otc already exists
# 400638
# otc already exists
# 400639
# df already exists
# Got all block data
# otc done
# 400640
# Got all block data
# otc done
# 400641
# Got all block data
# otc done
# 400642
# Got all block data
# otc done
# 400643
# Got all block data
# otc done
# 400644
# Got all block data
# otc done
# 400645
# Got all block data
# otc done
# 400646
# Got all block data
# otc done
# 400647
# Got all block data
# otc done
# 400648
# Got all block data
# otc done
# 400649
# Got all block data
# otc done
# 400650
# Got all block data
# otc done
# 400651
# Got all block data
# otc done
# 400652
# Got all block data
# otc done
# 400653
# Got all block data
# otc done
# 400654
# Got all block data
# otc done
# 400655
# Got all block data
# otc done
# 400656
# Got all block data
# otc done
# 400657
# Got all block data
# otc done
# 400658
# Got all block data
# otc done
# 400659
# Got all block data
# otc done
# 400660
# Got all block data
# otc done
# 400661
# Got all block data
# otc done
# 400662
# Got all block data
# otc done
# 400663
# Got all block data
# otc done
# 400664
# Got all block data
# otc done
# 400665
# Got all block data
# otc done
# 400666
# Got all block data
# otc done
# 400667
# Got all block data
# otc done
# 400668
# Got all block data
# otc done
# 400669
# Got all block data
# otc done
# 400670
# Got all block data
# otc done
# 400671
# Got all block data
# otc done
# 400672
# Got all block data
# otc done
# 400673
# Got all block data
# otc done
# 400674
# Got all block data
# otc done
# 400675
# Got all block data
# otc done
# 400676
# Got all block data
# otc done
# 400677
# Got all block data
# otc done
# 400678
# Got all block data
# otc done
# 400679
# Got all block data
# otc done
# 400680
# Got all block data
# otc done
# 400681
# Got all block data
# otc done
# 400682
# Got all block data
# otc done
# 400683
# Got all block data
# otc done
# 400684
# Got all block data
# otc done
# 400685
# Got all block data
# otc done
# 400686
# Got all block data
# otc done
# 400687
# Got all block data
# otc done
# 400688
# Got all block data
# otc done
# 400689
# Got all block data
# otc done
# 400690
# Got all block data
# otc done
# 400691
# Got all block data
# otc done
# 400692
# Got all block data
# otc done
# 400693
# Got all block data
# otc done
# 400694
# Got all block data
# otc done
# 400695
# Got all block data
# otc done
# 400696
# Got all block data
# otc done
# 400697
# Got all block data
# otc done
# 400698
# Got all block data
# otc done
# 400699
# Got all block data
# otc done
# 400700
# Got all block data
# otc done
# 400701
# Got all block data
# otc done
# 400702
# Got all block data
# otc done
# 400703
# Got all block data
# otc done
# 400704
# Got all block data
# otc done
# 400705
# Got all block data
# otc done
# 400706
# Got all block data
# otc done
# 400707
# Got all block data
# otc done
# 400708
# Got all block data
# otc done
# 400709
# Got all block data
# otc done
# 400710
# Got all block data
# otc done
# 400711
# Got all block data
# otc done
# 400712
# Got all block data
# otc done
# 400713
# Got all block data
# otc done
# 400714
# Got all block data
# otc done
# 400715
# Got all block data
# otc done
# 400716
# Got all block data
# otc done
# 400717
# Got all block data
# otc done
# 400718
# Got all block data
# otc done
# 400719
# Got all block data
# otc done
# 400720
# Got all block data
# otc done
# 400721
# Got all block data
# otc done
# 400722
# Got all block data
# otc done
# 400723
# Got all block data
# otc done
# 400724
# Got all block data
# otc done
# 400725
# Got all block data
# otc done
# 400726
# Got all block data
# otc done
# 400727
# Got all block data
# otc done
# 400728
# Got all block data
# otc done
# 400729
# Got all block data
# otc done
# 400730
# Got all block data
# otc done
# 400731
# Got all block data
# otc done
# 400732
# Got all block data
# otc done
# 400733
# Got all block data
# otc done
# 400734
# Got all block data
# otc done
# 400735
# Got all block data
# otc done
# 400736
# Got all block data
# otc done
# 400737
# Got all block data
# otc done
# 400738
# Got all block data
# otc done
# 400739
# Got all block data
# otc done
# 400740
# Got all block data
# otc done
# 400741
# Got all block data
# otc done
# 400742
# Got all block data
# otc done
# 400743
# Got all block data
# otc done
# 400744
# Got all block data
# otc done
# 400745
# Got all block data
# otc done
# 400746
# Got all block data
# otc done
# 400747
# Got all block data
# otc done
# 400748
# Got all block data
# otc done
# 400749
# Got all block data
# otc done
# 400750
# Got all block data
# otc done
# 400751
# Got all block data
# otc done
# 400752
# Got all block data
# otc done
# 400753
# Got all block data
# otc done
# 400754
# Got all block data
# otc done
# 400755
# Got all block data
# otc done
# 400756
# Got all block data
# otc done
# 400757
# Got all block data
# otc done
# 400758
# Got all block data
# otc done
# 400759
# Got all block data
# otc done
# 400760
# Got all block data
# otc done
# 400761
# Got all block data
# otc done
# 400762
# Got all block data
# otc done
# 400763
# Got all block data
# otc done
# 400764
# Got all block data
# otc done
# 400765
# Got all block data
# otc done
# 400766
# Got all block data
# otc done
# 400767
# Got all block data
# otc done
# 400768
# Got all block data
# otc done
# 400769
# Got all block data
# otc done
# 400770
# Got all block data
# otc done
# 400771
# Got all block data
# otc done
# 400772
# Got all block data
# otc done
# 400773
# Got all block data
# otc done
# 400774
# Got all block data
# otc done
# 400775
# Got all block data
# otc done
# 400776
# Got all block data
# otc done
# 400777
# Got all block data
# otc done
# 400778
# Got all block data
# otc done
# 400779
# Got all block data
# otc done
# 400780
# Got all block data
# otc done
# 400781
# Got all block data
# otc done
# 400782
# Got all block data
# otc done
# 400783
# Got all block data
# otc done
# 400784
# Got all block data
# otc done
# 400785
# Got all block data
# otc done
# 400786
# Got all block data
# otc done
# 400787
# Got all block data
# otc done
# 400788
# Got all block data
# otc done
# 400789
# Got all block data
# otc done
# 400790
# Got all block data
# otc done
# 400791
# Got all block data
# otc done
# 400792
# Got all block data
# otc done
# 400793
# Got all block data
# otc done
# 400794
# Got all block data
# otc done
# 400795
# Got all block data
# otc done
# 400796
# Got all block data
# otc done
# 400797
# Got all block data
# otc done
# 400798
# Got all block data
# otc done
# 400799
# Got all block data
# otc done
# 400800
# Got all block data
# otc done
# 400801
# Got all block data
# otc done
# 400802
# Got all block data
# otc done
# 400803
# Got all block data
# otc done
# 400804
# Got all block data
# otc done
# 400805
# Got all block data
# otc done
# 400806
# Got all block data
# otc done
# 400807
# Got all block data
# otc done
# 400808
# Got all block data
# otc done
# 400809
# Got all block data
# otc done
# 400810
# Got all block data
# otc done
# 400811
# Got all block data
# otc done
# 400812
# Got all block data
# otc done
# 400813
# Got all block data
# otc done
# 400814
# Got all block data
# otc done
# 400815
# Got all block data
# otc done
# 400816
# Got all block data
# otc done
# 400817
# Got all block data
# otc done
# 400818
# Got all block data
# otc done
# 400819
# Got all block data
# otc done
# 400820
# Got all block data
# otc done
# 400821
# Got all block data
# otc done
# 400822
# Got all block data
# otc done
# 400823
# Got all block data
# otc done
# 400824
# Got all block data
# otc done
# 400825
# otc already exists
# 400826
# Got all block data
# otc done
# 400827
# Got all block data
# otc done
# 400828
# Got all block data
# otc done
# 400829
# Got all block data
# otc done
# 400830
# Got all block data
# otc done
# 400831
# Got all block data
# otc done
# 400832
# Got all block data
# otc done
# 400833
# Got all block data
# otc done
# 400834
# Got all block data
# otc done
# 400835
# Got all block data
# otc done
# 400836
# Got all block data
# otc done
# 400837
# Got all block data
# otc done
# 400838
# Got all block data
# otc done
# 400839
# Got all block data
# otc done
# 400840
# Got all block data
# otc done
# 400841
# Got all block data
# otc done
# 400842
# Got all block data
# otc done
# 400843
# Got all block data
# otc done
# 400844
# Got all block data
# otc done
# 400845
# otc already exists
# 400846
# Got all block data
# otc done
# 400847
# Got all block data
# otc done
# 400848
# Got all block data
# otc done
# 400849
# Got all block data
# otc done
# 400850
# Got all block data
# otc done
# 400851
# Got all block data
# otc done
# 400852
# Got all block data
# otc done
# 400853
# Got all block data
# otc done
# 400854
# Got all block data
# otc done
# 400855
# Got all block data
# otc done
# 400856
# Got all block data
# otc done
# 400857
# Got all block data
# otc done
# 400858
# Got all block data
# otc done
# 400859
# Got all block data
# otc done
# 400860
# Got all block data
# otc done
# 400861
# Got all block data
# otc done
# 400862
# Got all block data
# otc done
# 400863
# Got all block data
# otc done
# 400864
# Got all block data
# otc done
# 400865
# Got all block data
# otc done
# 400866
# Got all block data
# otc done
# 400867
# Got all block data
# otc done
# 400868
# Got all block data
# otc done
# 400869
# Got all block data
# otc done
# 400870
# Got all block data
# otc done
# 400871
# Got all block data
# otc done
# 400872
# Got all block data
# otc done
# 400873
# Got all block data
# otc done
# 400874
# Got all block data
# otc done
# 400875
# Got all block data
# otc done
# 400876
# Got all block data
# otc done
# 400877
# Got all block data
# otc done
# 400878
# Got all block data
# otc done
# 400879
# Got all block data
# otc done
# 400880
# Got all block data
# otc done
# 400881
# Got all block data
# otc done
# 400882
# Got all block data
# otc done
# 400883
# Got all block data
# otc done
# 400884
# Got all block data
# otc done
# 400885
# Got all block data
# otc done
# 400886
# Got all block data
# otc done
# 400887
# Got all block data
# otc done
# 400888
# Got all block data
# otc done
# 400889
# Got all block data
# otc done
# 400890
# Got all block data
# otc done
# 400891
# Got all block data
# otc done
# 400892
# Got all block data
# otc done
# 400893
# Got all block data
# otc done
# 400894
# Got all block data
# otc done
# 400895
# Got all block data
# otc done
# 400896
# Got all block data
# otc done
# 400897
# Got all block data
# otc done
# 400898
# Got all block data
# otc done
# 400899
# Got all block data
# otc done
# 400900
# Got all block data
# otc done
# 400901
# Got all block data
# otc done
# 400902
# Got all block data
# otc done
# 400903
# Got all block data
# otc done
# 400904
# Got all block data
# otc done
# 400905
# Got all block data
# otc done
# 400906
# Got all block data
# otc done
# 400907
# Got all block data
# otc done
# 400908
# Got all block data
# otc done
# 400909
# otc already exists
# 400910
# Got all block data
# otc done
# 400911
# Got all block data
# otc done
# 400912
# Got all block data
# otc done
# 400913
# Got all block data
# otc done
# 400914
# Got all block data
# otc done
# 400915
# Got all block data
# otc done
# 400916
# Got all block data
# otc done
# 400917
# Got all block data
# otc done
# 400918
# Got all block data
# otc done
# 400919
# Got all block data
# otc done
# 400920
# Got all block data
# otc done
# 400921
# Got all block data
# otc done
# 400922
# Got all block data
# otc done
# 400923
# Got all block data
# otc done
# 400924
# Got all block data
# otc done
# 400925
# Got all block data
# otc done
# 400926
# Got all block data
# otc done
# 400927
# Got all block data
# otc done
# 400928
# Got all block data
# otc done
# 400929
# Got all block data
# otc done
# 400930
# Got all block data
# otc done
# 400931
# Got all block data
# otc done
# 400932
# Got all block data
# otc done
# 400933
# Got all block data
# otc done
# 400934
# Got all block data
# otc done
# 400935
# Got all block data
# otc done
# 400936
# Got all block data
# otc done
# 400937
# Got all block data
# otc done
# 400938
# Got all block data
# otc done
# 400939
# Got all block data
# otc done
# 400940
# Got all block data
# otc done
# 400941
# Got all block data
# otc done
# 400942
# Got all block data
# otc done
# 400943
# Got all block data
# otc done
# 400944
# Got all block data
# otc done
# 400945
# Got all block data
# otc done
# 400946
# Got all block data
# otc done
# 400947
# Got all block data
# otc done
# 400948
# Got all block data
# otc done
# 400949
# Got all block data
# otc done
# 400950
# Got all block data
# otc done
# 400951
# Got all block data
# otc done
# 400952
# Got all block data
# otc done
# 400953
# Got all block data
# otc done
# 400954
# Got all block data
# otc done
# 400955
# Got all block data
# otc done
# 400956
# Got all block data
# otc done
# 400957
# Got all block data
# otc done
# 400958
# Got all block data
# otc done
# 400959
# Got all block data
# otc done
# 400960
# Got all block data
# otc done
# 400961
# Got all block data
# otc done
# 400962
# Got all block data
# otc done
# 400963
# Got all block data
# otc done
# 400964
# Got all block data
# otc done
# 400965
# Got all block data
# otc done
# 400966
# Got all block data
# otc done
# 400967
# Got all block data
# otc done
# 400968
# Got all block data
# otc done
# 400969
# Got all block data
# otc done
# 400970
# Got all block data
# otc done
# 400971
# Got all block data
# otc done
# 400972
# Got all block data
# otc done
# 400973
# Got all block data
# otc done
# 400974
# Got all block data
# otc done
# 400975
# Got all block data
# otc done
# 400976
# Got all block data
# otc done
# 400977
# Got all block data
# otc done
# 400978
# Got all block data
# otc done
# 400979
# Got all block data
# otc done
# 400980
# Got all block data
# otc done
# 400981
# Got all block data
# otc done
# 400982
# Got all block data
# otc done
# 400983
# Got all block data
# otc done
# 400984
# Got all block data
# otc done
# 400985
# Got all block data
# otc done
# 400986
# Got all block data
# otc done
# 400987
# Got all block data
# otc done
# 400988
# Got all block data
# otc done
# 400989
# Got all block data
# otc done
# 400990
# Got all block data
# otc done
# 400991
# Got all block data
# otc done
# 400992
# Got all block data
# otc done
# 400993
# Got all block data
# otc done
# 400994
# Got all block data
# otc done
# 400995
# Got all block data
# otc done
# 400996
# Got all block data
# otc done
# 400997
# Got all block data
# otc done
# 400998
# Got all block data
# otc done
# 400999
# Got all block data
# otc done
# 401000
# Got all block data
# otc done
# 401001
# Got all block data
# otc done
# 401002
# Got all block data
# otc done
# 401003
# Got all block data
# otc done
# 401004
# Got all block data
# otc done
# 401005
# Got all block data
# otc done
# 401006
# Got all block data
# otc done
# 401007
# Got all block data
# otc done
# 401008
# Got all block data
# otc done
# 401009
# Got all block data
# otc done
# 401010
# Got all block data
# otc done
# 401011
# Got all block data
# otc done
# 401012
# Got all block data
# otc done
# 401013
# Got all block data
# otc done
# 401014
# Got all block data
# otc done
# 401015
# Got all block data
# otc done
# 401016
# Got all block data
# otc done
# 401017
# Got all block data
# otc done
# 401018
# Got all block data
# otc done
# 401019
# Got all block data
# otc done
# 401020
# Got all block data
# otc done
# 401021
# Got all block data
# otc done
# 401022
# Got all block data
# otc done
# 401023
# Got all block data
# otc done
# 401024
# Got all block data
# otc done
# 401025
# Got all block data
# otc done
# 401026
# Got all block data
# otc done
# 401027
# Got all block data
# otc done
# 401028
# Got all block data
# otc done
# 401029
# Got all block data
# otc done
# 401030
# Got all block data
# otc done
# 401031
# Got all block data
# otc done
# 401032
# Got all block data
# otc done
# 401033
# Got all block data
# otc done
# 401034
# Got all block data
# otc done
# 401035
# Got all block data
# otc done
# 401036
# Got all block data
# otc done
# 401037
# Got all block data
# otc done
# 401038
# Got all block data
# otc done
# 401039
# Got all block data
# otc done
# 401040
# Got all block data
# otc done
# 401041
# Got all block data
# otc done
# 401042
# Got all block data
# otc done
# 401043
# Got all block data
# otc done
# 401044
# Got all block data
# otc done
# 401045
# Got all block data
# otc done
# 401046
# Got all block data
# otc done
# 401047
# Got all block data
# otc done
# 401048
# Got all block data
# otc done
# 401049
# Got all block data
# otc done
# 401050
# Got all block data
# otc done
# 401051
# Got all block data
# otc done
# 401052
# Got all block data
# otc done
# 401053
# Got all block data
# otc done
# 401054
# Got all block data
# otc done
# 401055
# Got all block data
# otc done
# 401056
# Got all block data
# otc done
# 401057
# Got all block data
# otc done
# 401058
# Got all block data
# otc done
# 401059
# Got all block data
# otc done
# 401060
# Got all block data
# otc done
# 401061
# Got all block data
# otc done
# 401062
# Got all block data
# otc done
# 401063
# Got all block data
# otc done
# 401064
# Got all block data
# otc done
# 401065
# Got all block data
# otc done
# 401066
# Got all block data
# otc done
# 401067
# Got all block data
# otc done
# 401068
# Got all block data
# otc done
# 401069
# Got all block data
# otc done
# 401070
# Got all block data
# otc done
# 401071
# Got all block data
# otc done
# 401072
# Got all block data
# otc done
# 401073
# otc already exists
# 401074
# Got all block data
# otc done
# 401075
# Got all block data
# otc done
# 401076
# Got all block data
# otc done
# 401077
# Got all block data
# otc done
# 401078
# Got all block data
# otc done
# 401079
# Got all block data
# otc done
# 401080
# otc already exists
# 401081
# otc already exists
# 401082
# Got all block data
# otc done
# 401083
# Got all block data
# otc done
# 401084
# Got all block data
# otc done
# 401085
# Got all block data
# otc done
# 401086
# Got all block data
# otc done
# 401087
# Got all block data
# otc done
# 401088
# Got all block data
# otc done
# 401089
# Got all block data
# otc done
# 401090
# Got all block data
# otc done
# 401091
# otc already exists
# 401092
# Got all block data
# otc done
# 401093
# Got all block data
# otc done
# 401094
# Got all block data
# otc done
# 401095
# Got all block data
# otc done
# 401096
# Got all block data
# otc done
# 401097
# Got all block data
# otc done
# 401098
# Got all block data
# otc done
# 401099
# Got all block data
# otc done
# 401100
# Got all block data
# otc done
# 401101
# Got all block data
# otc done
# 401102
# Got all block data
# otc done
# 401103
# Got all block data
# otc done
# 401104
# Got all block data
# otc done
# 401105
# Got all block data
# otc done
# 401106
# otc already exists
# 401107
# Got all block data
# otc done
# 401108
# Got all block data
# otc done
# 401109
# otc already exists
# 401110
# Got all block data
# otc done
# 401111
# Got all block data
# otc done
# 401112
# Got all block data
# otc done
# 401113
# Got all block data
# otc done
# 401114
# Got all block data
# otc done
# 401115
# otc already exists
# 401116
# Got all block data
# otc done
# 401117
# Got all block data
# otc done
# 401118
# Got all block data
# otc done
# 401119
# Got all block data
# otc done
# 401120
# Got all block data
# otc done
# 401121
# Got all block data
# otc done
# 401122
# otc already exists
# 401123
# Got all block data
# otc done
# 401124
# Got all block data
# otc done
# 401125
# Got all block data
# otc done
# 401126
# Got all block data
# otc done
# 401127
# Got all block data
# otc done
# 401128
# Got all block data
# otc done
# 401129
# Got all block data
# otc done
# 401130
# Got all block data
# otc done
# 401131
# Got all block data
# otc done
# 401132
# Got all block data
# otc done
# 401133
# Got all block data
# otc done
# 401134
# Got all block data
# otc done
# 401135
# otc already exists
# 401136
# Got all block data
# otc done
# 401137
# Got all block data
# otc done
# 401138
# Got all block data
# otc done
# 401139
# Got all block data
# otc done
# 401140
# Got all block data
# otc done
# 401141
# Got all block data
# otc done
# 401142
# Got all block data
# otc done
# 401143
# Got all block data
# otc done
# 401144
# Got all block data
# otc done
# 401145
# Got all block data
# otc done
# 401146
# Got all block data
# otc done
# 401147
# Got all block data
# otc done
# 401148
# Got all block data
# otc done
# 401149
# Got all block data
# otc done
# 401150
# Got all block data
# otc done
# 401151
# Got all block data
# otc done
# 401152
# Got all block data
# otc done
# 401153
# Got all block data
# otc done
# 401154
# Got all block data
# otc done
# 401155
# Got all block data
# otc done
# 401156
# Got all block data
# otc done
# 401157
# Got all block data
# otc done
# 401158
# Got all block data
# otc done
# 401159
# Got all block data
# otc done
# 401160
# Got all block data
# otc done
# 401161
# Got all block data
# otc done
# 401162
# Got all block data
# otc done
# 401163
# Got all block data
# otc done
# 401164
# Got all block data
# otc done
# 401165
# Got all block data
# otc done
# 401166
# Got all block data
# otc done
# 401167
# Got all block data
# otc done
# 401168
# Got all block data
# otc done
# 401169
# Got all block data
# otc done
# 401170
# Got all block data
# otc done
# 401171
# Got all block data
# otc done
# 401172
# Got all block data
# otc done
# 401173
# Got all block data
# otc done
# 401174
# Got all block data
# otc done
# 401175
# Got all block data
# otc done
# 401176
# Got all block data
# otc done
# 401177
# Got all block data
# otc done
# 401178
# Got all block data
# otc done
# 401179
# Got all block data
# otc done
# 401180
# otc already exists
# 401181
# otc already exists
# 401182
# otc already exists
# 401183
# otc already exists
# 401184
# otc already exists
# 401185
# otc already exists
# 401186
# otc already exists
# 401187
# otc already exists
# 401188
# otc already exists
# 401189
# otc already exists
# 401190
# otc already exists
# 401191
# otc already exists
# 401192
# otc already exists
# 401193
# otc already exists
# 401194
# otc already exists
# 401195
# otc already exists
# 401196
# otc already exists
# 401197
# otc already exists
# 401198
# otc already exists
# 401199
# otc already exists
# 401200
# otc already exists
# 401201
# otc already exists
# 401202
# otc already exists
# 401203
# otc already exists
# 401204
# otc already exists
# 401205
# otc already exists
# 401206
# otc already exists
# 401207
# otc already exists
# 401208
# otc already exists
# 401209
# otc already exists
# 401210
# otc already exists
# 401211
# otc already exists
# 401212
# otc already exists
# 401213
# otc already exists
# 401214
# otc already exists
# 401215
# otc already exists
# 401216
# otc already exists
# 401217
# otc already exists
# 401218
# otc already exists
# 401219
# otc already exists
# 401220
# otc already exists
# 401221
# otc already exists
# 401222
# Got all block data
# otc done
# 401223
# Got all block data
# otc done
# 401224
# Got all block data
# otc done
# 401225
# Got all block data
# otc done
# 401226
# Got all block data
# otc done
# 401227
# Got all block data
# otc done
# 401228
# Got all block data
# otc done
# 401229
# otc already exists
# 401230
# Got all block data
# otc done
# 401231
# Got all block data
# otc done
# 401232
# Got all block data
# otc done
# 401233
# Got all block data
# otc done
# 401234
# Got all block data
# otc done
# 401235
# Got all block data
# otc done
# 401236
# Got all block data
# otc done
# 401237
# Got all block data
# otc done
# 401238
# Got all block data
# otc done
# 401239
# Got all block data
# otc done
# 401240
# Got all block data
# otc done
# 401241
# otc already exists
# 401242
# Got all block data
# otc done
# 401243
# Got all block data
# otc done
# 401244
# Got all block data
# otc done
# 401245
# Got all block data
# otc done
# 401246
# Got all block data
# otc done
# 401247
# Got all block data
# otc done
# 401248
# Got all block data
# otc done
# 401249
# Got all block data
# otc done
# 401250
# Got all block data
# otc done
# 401251
# Got all block data
# otc done
# 401252
# Got all block data
# otc done
# 401253
# Got all block data
# otc done
# 401254
# Got all block data
# otc done
# 401255
# Got all block data
# otc done
# 401256
# Got all block data
# otc done
# 401257
# Got all block data
# otc done
# 401258
# Got all block data
# otc done
# 401259
# Got all block data
# otc done
# 401260
# Got all block data
# otc done
# 401261
# Got all block data
# otc done
# 401262
# Got all block data
# otc done
# 401263
# Got all block data
# otc done
# 401264
# Got all block data
# otc done
# 401265
# Got all block data
# otc done
# 401266
# Got all block data
# otc done
# 401267
# Got all block data
# otc done
# 401268
# Got all block data
# otc done
# 401269
# Got all block data
# otc done
# 401270
# Got all block data
# otc done
# 401271
# Got all block data
# otc done
# 401272
# Got all block data
# otc done
# 401273
# Got all block data
# otc done
# 401274
# Got all block data
# otc done
# 401275
# Got all block data
# otc done
# 401276
# Got all block data
# otc done
# 401277
# Got all block data
# otc done
# 401278
# Got all block data
# otc done
# 401279
# Got all block data
# otc done
# 401280
# Got all block data
# otc done
# 401281
# Got all block data
# otc done
# 401282
# Got all block data
# otc done
# 401283
# Got all block data
# otc done
# 401284
# Got all block data
# otc done
# 401285
# Got all block data
# otc done
# 401286
# Got all block data
# otc done
# 401287
# Got all block data
# otc done
# 401288
# Got all block data
# otc done
# 401289
# Got all block data
# otc done
# 401290
# Got all block data
# otc done
# 401291
# Got all block data
# otc done
# 401292
# Got all block data
# otc done
# 401293
# Got all block data
# otc done
# 401294
# Got all block data
# otc done
# 401295
# Got all block data
# otc done
# 401296
# Got all block data
# otc done
# 401297
# Got all block data
# otc done
# 401298
# Got all block data
# otc done
# 401299
# Got all block data
# otc done
# 401300
# Got all block data
# otc done
# 401301
# Got all block data
# otc done
# 401302
# Got all block data
# otc done
# 401303
# Got all block data
# otc done
# 401304
# Got all block data
# otc done
# 401305
# Got all block data
# otc done
# 401306
# Got all block data
# otc done
# 401307
# Got all block data
# otc done
# 401308
# Got all block data
# otc done
# 401309
# Got all block data
# otc done
# 401310
# Got all block data
# otc done
# 401311
# Got all block data
# otc done
# 401312
# Got all block data
# otc done
# 401313
# Got all block data
# otc done
# 401314
# Got all block data
# otc done
# 401315
# Got all block data
# otc done
# 401316
# Got all block data
# otc done
# 401317
# Got all block data
# otc done
# 401318
# Got all block data
# otc done
# 401319
# Got all block data
# otc done
# 401320
# Got all block data
# otc done
# 401321
# Got all block data
# otc done
# 401322
# Got all block data
# otc done
# 401323
# Got all block data
# otc done
# 401324
# Got all block data
# otc done
# 401325
# Got all block data
# otc done
# 401326
# Got all block data
# otc done
# 401327
# Got all block data
# otc done
# 401328
# Got all block data
# otc done
# 401329
# Got all block data
# otc done
# 401330
# Got all block data
# otc done
# 401331
# Got all block data
# otc done
# 401332
# Got all block data
# otc done
# 401333
# Got all block data
# otc done
# 401334
# Got all block data
# otc done
# 401335
# Got all block data
# otc done
# 401336
# Got all block data
# otc done
# 401337
# Got all block data
# otc done
# 401338
# Got all block data
# otc done
# 401339
# Got all block data
# otc done
# 401340
# Got all block data
# otc done
# 401341
# Got all block data
# otc done
# 401342
# Got all block data
# otc done
# 401343
# Got all block data
# otc done
# 401344
# Got all block data
# otc done
# 401345
# Got all block data
# otc done
# 401346
# Got all block data
# otc done
# 401347
# Got all block data
# otc done
# 401348
# Got all block data
# otc done
# 401349
# Got all block data
# otc done
# 401350
# Got all block data
# otc done
# 401351
# Got all block data
# otc done
# 401352
# Got all block data
# otc done
# 401353
# Got all block data
# otc done
# 401354
# Got all block data
# otc done
# 401355
# Got all block data
# otc done
# 401356
# Got all block data
# otc done
# 401357
# Got all block data
# otc done
# 401358
# Got all block data
# otc done
# 401359
# Got all block data
# otc done
# 401360
# Got all block data
# otc done
# 401361
# Got all block data
# otc done
# 401362
# Got all block data
# otc done
# 401363
# Got all block data
# otc done
# 401364
# Got all block data
# otc done
# 401365
# Got all block data
# otc done
# 401366
# Got all block data
# otc done
# 401367
# Got all block data
# otc done
# 401368
# Got all block data
# otc done
# 401369
# Got all block data
# otc done
# 401370
# Got all block data
# otc done
# 401371
# Got all block data
# otc done
# 401372
# Got all block data
# otc done
# 401373
# Got all block data
# otc done
# 401374
# Got all block data
# otc done
# 401375
# Got all block data
# otc done
# 401376
# Got all block data
# otc done
# 401377
# Got all block data
# otc done
# 401378
# Got all block data
# otc done
# 401379
# Got all block data
# otc done
# 401380
# Got all block data
# otc done
# 401381
# Got all block data
# otc done
# 401382
# Got all block data
# otc done
# 401383
# Got all block data
# otc done
# 401384
# Got all block data
# otc done
# 401385
# Got all block data
# otc done
# 401386
# Got all block data
# otc done
# 401387
# Got all block data
# otc done
# 401388
# Got all block data
# otc done
# 401389
# Got all block data
# otc done
# 401390
# Got all block data
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/.local/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/.local/lib/python3.5/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# /usr/lib/python3.5/http/client.py in getresponse(self)
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#
# /usr/lib/python3.5/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /usr/lib/python3.5/http/client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-4-c405359ca9d5> in <module>()
#     121
#     122     for adr in addresses:
# --> 123         if seen_before_in(block, adr):
#     124             continue
#     125         elif seen_before_out(block, adr):
#
# <ipython-input-4-c405359ca9d5> in seen_before_in(block, adr)
#      61                     RETURN b2.height LIMIT 1
#      62                     """.format(**params)
# ---> 63     data_fr = query_database(query_string).to_data_frame()
#      64     if data_fr.empty:
#      65         return False
#
# <ipython-input-4-c405359ca9d5> in query_database(query)
#       2     # REMEMBER TO BE CONNECTED TO IMPERIAL WIFI!
#       3     graph_db = py2neo.Graph("https://dsi-bitcoin.doc.ic.ac.uk:7473/db/data/", auth=("adi", "aditi123"))
# ----> 4     return graph_db.run(query)
#       5
#       6 def get_block_data(blk):
#
# ~/.local/lib/python3.5/site-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     489         :return:
#     490         """
# --> 491         return self.begin(autocommit=True).run(cypher, parameters, **kwparameters)
#     492
#     493     def separate(self, subgraph):
#
# ~/.local/lib/python3.5/site-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     849         finally:
#     850             if not self.transaction:
# --> 851                 self.finish()
#     852
#     853     def process(self):
#
# ~/.local/lib/python3.5/site-packages/py2neo/database.py in finish(self)
#     858
#     859     def finish(self):
# --> 860         self.process()
#     861         if self.transaction:
#     862             self.transaction.close()
#
# ~/.local/lib/python3.5/site-packages/py2neo/database.py in process(self)
#     855         """
#     856         self._assert_unfinished()
# --> 857         self.session.sync()
#     858
#     859     def finish(self):
#
# ~/.local/lib/python3.5/site-packages/py2neo/internal/http.py in sync(self)
#     311         count = 0
#     312         try:
# --> 313             response = self.post(ref, {"statements": self._statements}, expected=(OK, CREATED))
#     314             if response.status == 201:
#     315                 location_path = urlsplit(response.headers["Location"]).path
#
# ~/.local/lib/python3.5/site-packages/py2neo/internal/http.py in post(self, ref, json, expected)
#     155             headers["Content-Type"] = "application/json"
#     156             json = json_dumps(json).encode('utf-8')
# --> 157         rs = self.request("POST", self.path + ref, headers=self.headers, body=json)
#     158         if rs.status not in expected:
#     159             self.raise_error(rs.status, rs.data)
#
# ~/.local/lib/python3.5/site-packages/py2neo/internal/http.py in request(self, method, url, fields, headers, **urlopen_kw)
#     132                 with catch_warnings():
#     133                     simplefilter("ignore")
# --> 134                     return self._http.request(method, url, fields, headers, **urlopen_kw)
#     135         except MaxRetryError:
#     136             raise ServiceUnavailable("Cannot send %s request to <%s>" % (method, url))
#
# ~/.local/lib/python3.5/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~/.local/lib/python3.5/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~/.local/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     636
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#     640
#
# ~/.local/lib/python3.5/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     365             # Read retry?
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#     369                 read -= 1
#
# ~/.local/lib/python3.5/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# ~/.local/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/.local/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                     # Remove the TypeError from the exception chain in Python 3;
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     386             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/.local/lib/python3.5/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /usr/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.5/http/client.py in _read_status(self)
#     264             # Presumably, the server closed the connection before
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#     268         try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))

# %%
# myNotebook = "./pickle_to_df.ipynb"

# %run $myNotebook

# %%
# addresses1 = list(df.oadr.value_counts()[df.oadr.value_counts()>1].index)
# addresses2 = list(df.oadr.value_counts()[df.oadr.value_counts()==1].index)

# %%
# not_seen = [adr for adr in addresses1[:5] if not seen_before_in(block, adr) and not seen_before_out(block, adr)]
