# %%
import pickle
# and later you can load it
with open('dt_gambling.pickle', 'rb') as f:
    clf = pickle.load(f)
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import pandas as pd
from ml import *
df = pd.read_pickle("./user_df_labelled_10.pickle")
df.category.value_counts()
# Out:
# unknown      726632
# exchanges     28710
# gambling       7521
# pool           1024
# mixed           143
# Name: category, dtype: int64

# %%
class_hist(df)

# %%
import numpy as np
Y = df.category
#classes, Y = np.unique(Y, return_inverse=True)
X = df.drop(columns = ["category"])

# %%
from collections import Counter
Counter(Y)

# %%
y_pred = clf.predict(X)

# %%
from collections import Counter

# %%
classes

# %%
scores(Y, y_pred)
# Out:
# Accuracy: 0.8814480394615835
# Recall: [0.9253112  0.6640625  0.51815182]
# Precision: [0.93650635 0.60750447 0.55871886]
# f1 score: [0.93087512 0.63452566 0.53767123]

# %%
plot_confusion_matrix(Y, y_pred, "decision_tree_downsampled_conf_matrix")
# Out:
# /homes/ac2917/.local/lib/python3.5/site-packages/pandas/core/computation/check.py:17: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# confusion matrix normalized:
