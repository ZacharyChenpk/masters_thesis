# %%
import pandas as pd 
from functools import reduce
import pickle
import time
from collections import defaultdict
import os

block_list = [400000]

df = pd.read_pickle('../../pickles/df/400000.pickle')

# New columns for number of input and output transaction ids
df['num_txo'] = df.groupby('id_t')['id_txo_out'].transform('nunique')
df['num_txi'] = df.groupby('id_t')['id_txi'].transform('nunique')
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
#CHANGE LATER TO QUERY DATABASE INSTEAD

def tx_from_iadr(iadr):
    return set(df['id_t'][df["iadr"] == iadr])

def tx_from_oadr(oadr):
    return set(df['id_t'][df["oadr"] == oadr])

def iadrs_from_tx(id_t):
    return set(df['iadr'][df["id_t"] == id_t])

def oadrs_from_tx(id_t):
    return set(df['oadr'][df["id_t"] == id_t])

def block_from_tx(id_t):
    return set(df['block_no'][df["id_t"] == id_t])

class Addr:
    def __init__(self):
        self.adr = None
        self.sending_tx = set()
        self.receiving_tx = set()
        self.blocks = set()
        self.adr_rec_from = set()
        self.adr_sent_to = set()
        self.iadr_shared = set()
        self.oadr_shared = set()

adrs = []
already_seen_adr = set()

for iadr in set(df.iadr):
    a = Addr()
    a.adr = iadr
    st = tx_from_iadr(iadr)
    rt = tx_from_oadr(iadr)
    a.sending_tx.update(st)
    a.receiving_tx.update(rt)
    for t in st:
        a.adr_sent_to.update(oadrs_from_tx(t))
        shared = iadrs_from_tx(t)
        shared.remove(iadr)
        if shared:
            a.iadr_shared.update(shared)
    for t in rt:
        a.adr_rec_from.update(iadrs_from_tx(t))
        shared = oadrs_from_tx(t)
        shared.remove(iadr)
        if shared:
            a.oadr_shared.update(shared)
    already_seen_adr.add(iadr)
    adrs.append(a)
    
for oadr in set(df.oadr):
    if oadr not in already_seen_adr:
        a = Addr()
        a.adr = oadr
        rt = tx_from_oadr(oadr)
        a.receiving_tx.update(rt)
        for t in rt:
            a.adr_rec_from.update(iadrs_from_tx(t))
            shared = oadrs_from_tx(t)
            shared.remove(oadr)
            if shared:
                a.oadr_shared.update(shared)
        already_seen_adr.add(oadr) 
        adrs.append(a)

# %%
#WHICH addrS IN HAVE TRANSACTED WITH EACH OTHER
edges = []
for adr in adrs:
    a_s=adr.adr_sent_to
    a_r=adr.adr_rec_from
    if(a_s):
        for sadr in a_s:
            edges.append((adr.adr,sadr)) 
    if(a_r):
        for radr in a_r:
            edges.append((radr,adr.adr))

# %%
_adrs = [_adr.adr for _adr in adrs]
_num_iadr_shared = [len(_adr.iadr_shared) for _adr in adrs]
_num_oadr_shared = [len(_adr.oadr_shared) for _adr in adrs]
_num_send_tx = [len(_adr.sending_tx) for _adr in adrs]
_num_rec_tx = [len(_adr.receiving_tx) for _adr in adrs]

# %%
adr_df = pd.DataFrame(_adrs,columns=['addrs'])
adr_df['num_iadr_shared'] = _num_iadr_shared
adr_df['num_oadr_shared'] = _num_oadr_shared
adr_df['num_send_tx'] = _num_send_tx
adr_df['num_rec_tx'] = _num_rec_tx
adr_df['category'] = 'unknown'

# %%
adr_df=adr_df.set_index('addrs')

# %%
adr_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Tag addresses

# %%
#Dictionary structure - 
#'Address': 'Category'
categories = ['exchanges','gambling','pool']
dic_addrlabels = defaultdict(set)
starttime = time.time() 

for category in categories:
    #for block in range(first_block,last_block+1,1):
    for block in block_list:
        category_df = pd.read_pickle('../../pickles/categories/{}.pickle'.format(category))
        addr = category_df.loc[category_df['last used in block'] == block]['address'].tolist()
        if(len(addr)!=0):
            for a in addr:
                dic_addrlabels[a].add(category)
print("Total time to dict:", time.time()-starttime)
# Out:
# Total time to dict: 2.1810550689697266

# %%
for key in dic_addrlabels:
    adr_df.loc[key, 'category'] = dic_addrlabels[key] #label[cat.pop()]

# %%
adr_df.loc[adr_df['category']=='gambling']
# Out:
#                                     num_iadr_shared  num_oadr_shared  \
# addrs
# 15gtRnEf5b9CJkZMJumSHQt5MZ4wsGN3YS              2.0              0.0
# 1JucpVXi8y2qhaBRBSKhWGevp7S1VDyaxQ              4.0              0.0
# 13NC16UNvzbHyYXx6DZ4xHCUiWpAQUJdMv              1.0              0.0
# 17j17fVyEWoFUJ6UgMfqGtvpadjsHdQYTz              1.0              0.0
# 13BLhErvZFiWgMJraszMhDBESVx3hBkYTG              1.0              0.0
# 1JjWjXb96d9MhjvGTLKyhLTwsa6jE5UDK7              2.0              0.0
# 1PsHD2NEjE6NNpHqLyKkM5SJ3BeC5mJKT4              2.0              0.0
# 18LPBKxMCWRp3bKADSVTyeSfcFE72aCsRY              2.0              0.0
# 1FSWny7ApdqKQExFhQNaFfrHAE5gL2KarK              1.0              0.0
# 1DHLo1H1g18Dc74K1cM4KXc8FqWSsaZZXh              2.0              0.0
#
#                                     num_send_tx  num_rec_tx  category
# addrs
# 15gtRnEf5b9CJkZMJumSHQt5MZ4wsGN3YS          1.0         0.0  gambling
# 1JucpVXi8y2qhaBRBSKhWGevp7S1VDyaxQ          1.0         0.0  gambling
# 13NC16UNvzbHyYXx6DZ4xHCUiWpAQUJdMv          1.0         0.0  gambling
# 17j17fVyEWoFUJ6UgMfqGtvpadjsHdQYTz          1.0         0.0  gambling
# 13BLhErvZFiWgMJraszMhDBESVx3hBkYTG          1.0         0.0  gambling
# 1JjWjXb96d9MhjvGTLKyhLTwsa6jE5UDK7          1.0         0.0  gambling
# 1PsHD2NEjE6NNpHqLyKkM5SJ3BeC5mJKT4          1.0         0.0  gambling
# 18LPBKxMCWRp3bKADSVTyeSfcFE72aCsRY          1.0         0.0  gambling
# 1FSWny7ApdqKQExFhQNaFfrHAE5gL2KarK          1.0         0.0  gambling
# 1DHLo1H1g18Dc74K1cM4KXc8FqWSsaZZXh          1.0         0.0  gambling

# %%
adr_df.loc[adr_df['category']=='exchanges']
# Out:
#                                     num_iadr_shared  num_oadr_shared  \
# addrs
# 1441rifvAnExK365RZuaPuUWsQGtYWqsSY              4.0              0.0
# 1HtooD698CMWW9uYvfQRfvoa3Nt2kdC2km              4.0              0.0
# 1JxqQUEeZ5dC4P4bCRwW9xme82yXLLYsPc              4.0              0.0
# 1LpT8GNd5gRNyKgHKoBcwDW6bbTPvhCc9X              5.0              0.0
# 16YchKoXAXwpRJks9BbJZGygNPYhwQzNbN              3.0              0.0
# 1FZ9K3BTxT7oeBpEcvHVGukkAtbczypgaD              4.0              0.0
# 1ERESTq7ufNodrc6an5YQ7x8iNFzEZ4hs2              3.0              0.0
# 1KU42ApFSNP5c44UcBBVMMLMTux1jdcN2f              1.0              0.0
# 1EVoefJTsZJuBZyQVBeJkfVxsu61DVusfH              3.0              0.0
# 1DXiKVVPV8V8vWYSXH6fWfkAyrUTTazhHh              4.0              0.0
# 3KBYVUv7XysS4BDpEXmePLwvptHpwqHckH              NaN              NaN
# 3AJA8HguH29HpKNWajbGGYErEbcibLFEAe              NaN              NaN
# 38W6NThtSR2ELtTtRUryWte73FVrpiRAXQ              NaN              NaN
# 3Q1ax378icfQSZtE9ddRYnu2RYcivcP5yh              NaN              NaN
#
#                                     num_send_tx  num_rec_tx   category
# addrs
# 1441rifvAnExK365RZuaPuUWsQGtYWqsSY          1.0         0.0  exchanges
# 1HtooD698CMWW9uYvfQRfvoa3Nt2kdC2km          1.0         0.0  exchanges
# 1JxqQUEeZ5dC4P4bCRwW9xme82yXLLYsPc          1.0         0.0  exchanges
# 1LpT8GNd5gRNyKgHKoBcwDW6bbTPvhCc9X          1.0         0.0  exchanges
# 18npfKrF87dZBV2avp6igrtRLkRusZdTqm          1.0         0.0  exchanges
# 14dqcCYtUbhBUBh2bQTXCHJe5M9cR3ghjZ          1.0         0.0  exchanges
# 1BX4SXckndvKLvyJeYPvAS4kqBJXSxuNxo          1.0         0.0  exchanges
# 1MVYWCg8GQNNgsy63EKCy1NCrMPpLWAgPx          1.0         0.0  exchanges
# 17iD9njg7HSEX5f9ZdrMfgzCHXqLsiSTDX          1.0         0.0  exchanges
# 1LXnbEGeWDaiEn4gyFks77FFrEWaBYbqaT          1.0         0.0  exchanges
# 1LzuZNp1gh5tFfNCbGkx3zb6HGcE1YoEst          1.0         0.0  exchanges
# 1DmoPi7RpKQUSCP6TtwavigCN6ECbHpQuf          1.0         0.0  exchanges
# 1LkgsVxVNjMETYQ8NCz9yWxfvpnfpxZEiJ          1.0         0.0  exchanges
# 14XuD2p2RtESyEZo4msNUbEh5pURQt2Aov          1.0         0.0  exchanges
# 1KBrCDn9n5JXxMib2YNw85Z61rjweB2xzb          1.0         0.0  exchanges
# 1FgPHUZVjZMeKgr2qG2qnhpYp21z5qZPQz          1.0         0.0  exchanges
# 1Mp1B4eqRsWELESe6EQUwWt9PuZqGt2trW          1.0         0.0  exchanges
# 1KbipkSei9X2dUwmttLpxihoK5ixqNY5TT          1.0         0.0  exchanges
# 1B5W6NqvhBz2n7L7CwCbGKHS8Dr2iNTZmd          1.0         0.0  exchanges
# 1GfWSKgpKH9fsYeJtysnFGbpoHJPZ39AL5          1.0         0.0  exchanges
# 1Gji3n8wzn6qJYYQoNefsHTr7oz9SGchHv          1.0         0.0  exchanges
# 1MH4qxb8FjuzzMNq7RT8AGwowJLtNmwywe          1.0         0.0  exchanges
# 1jokMWZRYBibCkk1WxvSj2wrPrcLHqWrm           1.0         0.0  exchanges
# 1GRkptYXGzyTbmnwYsfPgEF4Qwix41T8iW          1.0         0.0  exchanges
# 1FqUW6KqdvpD6Vws9ihknjg8Wz1AHBVagx          1.0         0.0  exchanges
# 1C7drXtyozzjRDdoBRHRW9a4RdgybTkvfu          1.0         0.0  exchanges
# 16afu8G78kEMTntkaMEggxZuUeKw96vtBx          1.0         0.0  exchanges
# 18Gf5BBgeDt5jqRBnUZC3MPiY2QtkQphui          1.0         0.0  exchanges
# 1LJBicvpfNqj41UEn9MUckRQauJBEmtcvs          1.0         0.0  exchanges
# 1DLny3NENTcGnzkURkKHHnC1x6DHZnf1sk          1.0         0.0  exchanges
# 1LctrEmK7j7GVMbY9TmmcW2cVZAKDUFCxF          1.0         0.0  exchanges
# 1EQCdoZmkY5BarYGtjoyxqzD5Nk1ddwDgy          1.0         0.0  exchanges
# 1AagpmVSSNmJW51gKt6cusuHBaraaTPka9          1.0         0.0  exchanges
# 1vFLTqgZAnivJmUR1KnN7HjnMZA7k2U9W           1.0         0.0  exchanges
# 1MjtjsowTshuYhWevAMAHCiHr61cJvKpqt          1.0         0.0  exchanges
# 1DD5n86iUq9u7uSWh4sVNtJYsDYwLdTRvb          1.0         0.0  exchanges
# 17eT8yv5kDY3XT1AX1tPfJBSDFcfW2qcu5          1.0         0.0  exchanges
# 19z35J9k7Xotq2XNeRdyXdskhYjsu8sqiU          1.0         0.0  exchanges
# 1AsnwHeemVgeMucXEDNjr9d7MfB1DHXuPh          1.0         0.0  exchanges
# 1AwXcB6ifnDvPVj48deA2CnRrnegfm11QW          1.0         0.0  exchanges
# 16YchKoXAXwpRJks9BbJZGygNPYhwQzNbN          1.0         0.0  exchanges
# 1FZ9K3BTxT7oeBpEcvHVGukkAtbczypgaD          1.0         0.0  exchanges
# 1ERESTq7ufNodrc6an5YQ7x8iNFzEZ4hs2          1.0         0.0  exchanges
# 1KU42ApFSNP5c44UcBBVMMLMTux1jdcN2f          1.0         0.0  exchanges
# 1EVoefJTsZJuBZyQVBeJkfVxsu61DVusfH          1.0         0.0  exchanges
# 1DXiKVVPV8V8vWYSXH6fWfkAyrUTTazhHh          1.0         0.0  exchanges
# 3KBYVUv7XysS4BDpEXmePLwvptHpwqHckH          NaN         NaN  exchanges
# 3AJA8HguH29HpKNWajbGGYErEbcibLFEAe          NaN         NaN  exchanges
# 38W6NThtSR2ELtTtRUryWte73FVrpiRAXQ          NaN         NaN  exchanges
# 3Q1ax378icfQSZtE9ddRYnu2RYcivcP5yh          NaN         NaN  exchanges

# %%
df.loc[df['oadr']=='3KBYVUv7XysS4BDpEXmePLwvptHpwqHckH']
# Out:
# Empty DataFrame
# Columns: [iadr, id_t, id_txi, id_txo_in, id_txo_out, input_val, oadr, output_val, num_txo, num_txi]
# Index: []

# %%
for i, adr in enumerate(adrs):
    if adr.adr == '3KBYVUv7XysS4BDpEXmePLwvptHpwqHckH':
        
        print(i)
